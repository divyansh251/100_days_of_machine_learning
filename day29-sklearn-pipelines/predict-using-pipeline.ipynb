# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([
    [2, 'male', 31.0, 0, 0, 10.5, 'S'],
    [3, 'female', 25.0, 1, 0, 7.9, 'S'],
    [4, 'male', 40.0, 0, 1, 20.0, 'S']
], dtype=object)
test_input2
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S'],
#        [3, 'female', 25.0, 1, 0, 7.9, 'S'],
#        [4, 'male', 40.0, 0, 1, 20.0, 'S']], dtype=object)

# %%
pipe.predict(test_input2)
# Out:
# /home/divyansh/ML Content/jupyter_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/divyansh/ML Content/jupyter_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0, 0, 0])
